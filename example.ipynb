# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
url = 'http://openapi.seoul.go.kr:8088/61744c4c4d6e736835364b57576947/xml/TbgisTrdhlRelmW/1/1000/'
response = requests.get(url)
# XML 데이터 파싱
root = ET.fromstring(response.content)
# 데이터 추출
data = []
for row in root.iter('row'):
    row_data = {}
    for child in row:
        row_data[child.tag] = child.text
    data.append(row_data)
# 데이터프레임으로 변환
df = pd.DataFrame(data)

# %%
df
# Out:
#     ALLEY_TRDAR_CD ALLEY_TRDAR_NM XCNTS_VALUE YDNTS_VALUE SIGNGU_CD  \
# 0          3110006        부암동주민센터      196709      454726     11110
# 1          3110031         창신역 1번      201296      453318     11110
# 2          3110022         경신고등학교      199983      454394     11110
# 3          3110001         이북5도청사      196218      456645     11110
# 4          3110013       체부동홍종문가옥      197333      453207     11110
# ..             ...            ...         ...         ...       ...
# 995        3111003         삼전역 4번      207280      444963     11710
# 996        3111043           마천공원      212870      444679     11710
# 997        3111023         문정역 1번      210888      443156     11710
# 998        3111039        벌말어린이공원      212369      444689     11710
# 999        3111026         문정역 2번      211153      442755     11710
#
#     SIGNGU_CD_NM ADSTRD_CD ADSTRD_CD_NM RELM_AR
# 0            종로구  11110550          부암동  509683
# 1            종로구  11110690         창신3동  331338
# 2            종로구  11110650          혜화동  532515
# 3            종로구  11110560          평창동  565184
# 4            종로구  11110530          사직동  246646
# ..           ...       ...          ...     ...
# 995          송파구  11710650         잠실본동  932427
# 996          송파구  11710550         마천2동  472530
# 997          송파구  11710641         문정1동  422226
# 998          송파구  11710570          오금동  456514
# 999          송파구  11710641         문정1동  598355
#
# [1000 rows x 9 columns]
